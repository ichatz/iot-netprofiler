# %%
import pandas, numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt
import json
from pprint import pprint

# %% [markdown]
# Parsing json data

# %%
with open('./data json/test_nom_2018-11-09_08_55_11.json') as f:
    data = json.load(f)

pprint(head(data))
# Out:
# {'aaaa::212:7402:2:202:': {'max_rtt': 2843.0,
#                            'min_rtt': 454.0,
#                            'pkts': [{'pkt': 0.0, 'rtt': 1047.0, 'ttl': 63.0},
#                                     {'pkt': 1.0, 'rtt': 904.0, 'ttl': 63.0},
#                                     {'pkt': 2.0, 'rtt': 839.0, 'ttl': 63.0},
#                                     {'pkt': 3.0, 'rtt': 761.0, 'ttl': 63.0},
#                                     {'pkt': 4.0, 'rtt': 836.0, 'ttl': 63.0},
#                                     {'pkt': 5.0, 'rtt': 813.0, 'ttl': 63.0},
#                                     {'pkt': 6.0, 'rtt': 1415.0, 'ttl': 63.0},
#                                     {'pkt': 7.0, 'rtt': 1218.0, 'ttl': 63.0},
#                                     {'pkt': 8.0, 'rtt': 1564.0, 'ttl': 63.0},
#                                     {'pkt': 9.0, 'rtt': 1551.0, 'ttl': 63.0},
#                                     {'pkt': 10.0, 'rtt': 1592.0, 'ttl': 63.0},
# ...
