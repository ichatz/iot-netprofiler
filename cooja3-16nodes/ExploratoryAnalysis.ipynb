# %%
import pandas as pd
import numpy as np
from scipy import stats as sp
import matplotlib.pyplot as plt
import sys, os
sys.path.append('../')
import trace_analysis
import plots_analysis

# %%
plots = [("traces/normal/", 'grid_normal_2019-02-19_21'),
         ("traces/1bh-7/", 'grid_1bh-9_2019-02-20_00'),
         ("traces/1bh-9/", 'grid9_1bh-9_2019-02-13_15:57'),
         ("traces/1gh30-7/", 'grid_1gh30-7_2019-02-19_22'),
         ("traces/1gh30-9/", 'grid_1gh30-9_2019-02-20_00'),
         ("traces/1gh50-7/", 'grid_1gh50-7_2019-02-19_22'),
         ("traces/1gh50-9/", 'grid_1gh50-9_2019-02-19_23'),
         ("traces/1gh70-7/", 'grid_1gh70-7_2019-02-19_23'),
         ("traces/1gh70-9/", 'grid_1gh70-9_2019-02-19_23')
        ]

for row in plots:
    nodes, packets_node = trace_analysis.process_cooja2_traces(row[0], row[1])
    clean = trace_analysis.separate_outliers_by_node(packets_node)
    plots_analysis.plot_histograms_hops_nodes(nodes, clean, 1000, 0.018, row[1])
# Out:
# Invalid IHDR data. Cannot save the image grid_1bh-9_2019-02-20_00hist.png
# Invalid IHDR data. Cannot save the image grid9_1bh-9_2019-02-13_15:57hist.png

# %% [markdown]
# Tumbling windows

# %%
for row in plots:
    nodes, packets_node = trace_analysis.process_cooja2_traces(row[0], row[1])
    clean = trace_analysis.separate_outliers_by_node(packets_node)
    plots_analysis.plot_tumbling_windows_hops_nodes(nodes, clean, 200, 2000, row[1], 10)
# Out:
# Invalid IHDR data. Cannot save the image grid_1bh-9_2019-02-20_00-tumbling.png
# Invalid IHDR data. Cannot save the image grid9_1bh-9_2019-02-13_15:57-tumbling.png

# %% [markdown]
# Outliers => points our of mean-2std <= x(t) <= mean + 2std

# %%
for row in plots:
    nodes, packets_node = trace_analysis.process_cooja2_traces(row[0], row[1])
    outliers = trace_analysis.compute_outliers_by_node(packets_node)
    plots_analysis.plot_histograms_outliers_hops_nodes(nodes, outliers, 3500, 0.02, row[1])
# Out:
# Invalid IHDR data. Cannot save the image grid_1bh-9_2019-02-20_00-out-hist.png
# Invalid IHDR data. Cannot save the image grid9_1bh-9_2019-02-13_15:57-out-hist.png

# %% [markdown]
# IQR outliers

# %%
for row in plots:
    nodes, packets_node = trace_analysis.process_cooja2_traces(row[0], row[1])
    iqr_outliers = trace_analysis.compute_outliers_by_node(packets_node)
    plots_analysis.plot_histograms_iqr_outliers_hops_nodes(nodes, iqr_outliers, 3500, 0.02, row[1])
# Out:
# Invalid IHDR data. Cannot save the image grid_1bh-9_2019-02-20_00-out-iqr-hist.png
# Invalid IHDR data. Cannot save the image grid9_1bh-9_2019-02-13_15:57-out-iqr-hist.png
